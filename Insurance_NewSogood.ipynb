# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Locating & Importing Data

# %% [markdown]
# #### Library

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ##### Data Location

# %%
curr_location = os.getcwd()
raw_data_dir = 'Rawdata'
raw_data_name = 'Customer Data.csv'
raw_data_path = os.path.join(curr_location, raw_data_dir, raw_data_name)

# %% [markdown]
# #### Import Data

# %%
raw_data = pd.read_csv(raw_data_path)
raw_data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# ### Exploring Data

# %% [markdown]
# #### Cleaning Data

# %%
print(raw_data.isna().sum().sum())
cleaned_data = raw_data.dropna().reindex().copy()
cleaned_data.isna().sum().sum()
# Out:
# 314
# 0

# %% [markdown]
# #### Details of Data

# %% [markdown]
# ##### Objective : To increase insurance market value of insurance advertisement using credit card customer data

# %%
data_column = cleaned_data.columns.tolist()
cleaned_data.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
cleaned_data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8636.000000        8636.000000   8636.000000       8636.000000
# mean    1601.224893           0.895035   1025.433874        604.901438
# std     2095.571300           0.207697   2167.107984       1684.307803
# min        0.000000           0.000000      0.000000          0.000000
# 25%      148.095189           0.909091     43.367500          0.000000
# 50%      916.855459           1.000000    375.405000         44.995000
# 75%     2105.195853           1.000000   1145.980000        599.100000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8636.000000   8636.000000          8636.000000
# mean               420.843533    994.175523             0.496000
# std                917.245182   2121.458303             0.401273
# min                  0.000000      0.000000             0.000000
# ...

# %%
cleaned_data_correlation = cleaned_data.corr()
sns.heatmap(cleaned_data_correlation, annot=True)
# Out:
# /var/folders/0q/_7vdy7d50zn56_ss9skct64m0000gn/T/ipykernel_32741/1097414892.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cleaned_data_correlation = cleaned_data.corr()
# <AxesSubplot: >

# %%
mean_corr = cleaned_data_correlation.mean()
std_corr = cleaned_data_correlation.std()

# %%
print(mean_corr)
print(mean_corr.index)
# Out:
# BALANCE                             0.243276
# BALANCE_FREQUENCY                   0.178600
# PURCHASES                           0.344767
# ONEOFF_PURCHASES                    0.290028
# INSTALLMENTS_PURCHASES              0.282007
# CASH_ADVANCE                        0.166082
# PURCHASES_FREQUENCY                 0.235854
# ONEOFF_PURCHASES_FREQUENCY          0.243390
# PURCHASES_INSTALLMENTS_FREQUENCY    0.204538
# CASH_ADVANCE_FREQUENCY              0.110617
# CASH_ADVANCE_TRX                    0.149742
# PURCHASES_TRX                       0.327281
# CREDIT_LIMIT                        0.273186
# PAYMENTS                            0.316696
# MINIMUM_PAYMENTS                    0.142693
# PRC_FULL_PAYMENT                    0.073971
# TENURE                              0.102138
# dtype: float64
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
# ...

# %% [markdown]
# #### Function in Exploring Data

# %%
def correlation_sorter():
# Out:
#   Cell In [67], line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing
